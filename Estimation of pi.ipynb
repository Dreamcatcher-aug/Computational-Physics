# %%
import random

# %%
#实验次数 （可根据实际情况更改）
nexp = 100000
#命中次数
countnum = 0

# %%
for i in range(1,nexp+1):
    x = random.random()
    y = random.random()
    if x**2 + y**2 < 1:
        countnum += 1

pi = countnum / nexp *4
print(pi)
# Out:
# 3.14796
